# %% [markdown]
# # Optional Lab: Classification
# In this optional lab, you’ll get to take a look at what happens when you try to use linear regression for classification on categorical data. You can see an interactive plot that attempts to classify between two categories. And you may notice that this doesn’t work very well, which is okay, because that motivates the need for a different model (logistic regression model) to do classification tasks.
#
# In this lab, you will contrast regression and classification.

# %%
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from lab_utils_common import dlc, plot_data
from plt_one_addpt_onclick import plt_one_addpt_onclick
plt.style.use('./deeplearning.mplstyle')

# %% [markdown]
# ## Classification Problems
# <img align="left" src="./images/C1_W3_Classification.png"     style=" width:380px; padding: 10px; " > Examples of classification problems are things like: identifying email as Spam or Not Spam or determining if a tumor is malignant or benign. In particular, these are examples of *binary* classification where there are two possible outcomes.  Outcomes can be  described in pairs of 'positive'/'negative' such as 'yes'/'no, 'true'/'false' or '1'/'0'.
#
# Plots of classification data sets often use symbols to indicate the outcome of an example. In the plots below, 'X' is used to represent the positive values while 'O' represents negative outcomes.

# %% [markdown]
# The code below is used for visualizing a binary classification dataset with both one-variable and two-variable input features.

# %%
x_train = np.array([0., 1, 2, 3, 4, 5]) #A 1D NumPy array representing input features (single feature for each training example).
y_train = np.array([0,  0, 0, 1, 1, 1]) #A 1D NumPy array with labels (binary classification: 0 or 1).
X_train2 = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]]) #: A 2D NumPy array, where each row represents a training example with two features.
y_train2 = np.array([0, 0, 0, 1, 1, 1]) #The corresponding labels (same binary classification).
print(y_train)
# Out:
# [0 0 0 1 1 1]

# %%
#Identifying Positive and Negative Classes:
pos = y_train == 1 #pos creates a Boolean mask where True represents elements in y_train that are 1 (positive class).
neg = y_train == 0 #neg creates a Boolean mask where True represents elements in y_train that are 0 (negative class).
    # y_train == 1 → [False, False, False, True, True, True] (pos)
    # y_train == 0 → [True, True, True, False, False, False] (neg)
    # So, the elements where y_train equals 1 are True in pos, and the elements where y_train equals 0 are True in neg. This ensures that when plotting, we correctly identify and display the positive (y=1) and negative (y=0) examples.


# Creating the Plot (One Variable and Two Variables)
fig,ax = plt.subplots(1,2,figsize=(8,3)) #This creates a figure with two subplots, placed side by side (1 row, 2 columns).
#plot 1, single variable
ax[0].scatter(x_train[pos], y_train[pos], marker='x', s=80, c = 'red', label="y=1")
ax[0].scatter(x_train[neg], y_train[neg], marker='o', s=100, label="y=0", facecolors='none', 
              edgecolors=dlc["dlblue"],lw=3)

#Adjusts the y-axis limits, labels, title, and adds a legend
ax[0].set_ylim(-0.08,1.1)
ax[0].set_ylabel('y', fontsize=12)
ax[0].set_xlabel('x', fontsize=12)
ax[0].set_title('one variable plot')
ax[0].legend()

#plot 2, two variables
plot_data(X_train2, y_train2, ax[1])
#Sets axis limits, labels for x_0 and x_1, and adds a title & legend
ax[1].axis([0, 4, 0, 4]) 
ax[1].set_ylabel('$x_1$', fontsize=12)
ax[1].set_xlabel('$x_0$', fontsize=12)
ax[1].set_title('two variable plot')
ax[1].legend()
plt.tight_layout()
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# Note in the plots above:
# - In the single variable plot, positive results are shown both a red 'X's and as y=1. Negative results are blue 'O's and are located at y=0.
#    - Recall in the case of linear regression, y would not have been limited to two values but could have been any value.
# - In the two-variable plot, the y axis is not available.  Positive results are shown as red 'X's, while negative results use the blue 'O' symbol.
#     - Recall in the case of linear regression with multiple variables, y would not have been limited to two values and a similar plot would have been three-dimensional.

# %% [markdown]
# ## Linear Regression approach
# In the previous week, you applied linear regression to build a prediction model. Let's try that approach here using the simple example that was described in the lecture. The model will predict if a tumor is benign or malignant based on tumor size.  Try the following:
# - Click on 'Run Linear Regression' to find the best linear regression model for the given data.
#     - Note the resulting linear model does **not** match the data well.
# One option to improve the results is to apply a *threshold*.
# - Tick the box on the 'Toggle 0.5 threshold' to show the predictions if a threshold is applied.
#     - These predictions look good, the predictions match the data
# - *Important*: Now, add further 'malignant' data points on the far right, in the large tumor size range (near 10), and re-run linear regression.
#     - Now, the model predicts the larger tumor, but data point at x=3 is being incorrectly predicted!
# - to clear/renew the plot, rerun the cell containing the plot command.

# %%
w_in = np.zeros((1))
b_in = 0
plt.close('all') 
addpt = plt_one_addpt_onclick( x_train,y_train, w_in, b_in, logistic=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       2 b_in = 0
#       3 plt.close('all')
# ----> 4 addpt = plt_one_addpt_onclick( x_train,y_train, w_in, b_in, logistic=False)
#
# File c:\PYTHON ELEMENTARY\machine-learning-specialization-andrew-ng\Week 3\plt_one_addpt_onclick.py:66, in plt_one_addpt_onclick.__init__(self, x, y, w, b, logistic)
#      64 self.bthresh = CheckButtons(axthresh, ('Toggle 0.5 threshold (after regression)',))
#      65 self.bthresh.on_clicked(self.thresh)
# ---> 66 self.resize_sq(self.bthresh)
#
# File c:\PYTHON ELEMENTARY\machine-learning-specialization-andrew-ng\Week 3\plt_one_addpt_onclick.py:179, in plt_one_addpt_onclick.resize_sq(self, bcid)
#     171 """ resizes the check box """
#     172 #future reference
#     173 #print(f"width  : {bcid.rectangles[0].get_width()}")
# ...

# %% [markdown]
# The example above demonstrates that the linear model is insufficient to model categorical data. The model can be extended as described in the following lab. In the next optional lab you can see a plot similar to this one that uses sigmoid function (also called the logistic function) so as to do better on classification tasks that you saw in this lab.

# %% [markdown]
# ## Congratulations!
# In this lab you:
# - explored categorical data sets and plotting
# - determined that linear regression was insufficient for a classification problem.
